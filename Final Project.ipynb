# %%
# FINAL PROJECT
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Go to kaggle.com, find and download a data set that you find interesting
# Import your data-set
df = pd.read_csv("test.csv")

# %%
# Clean your data set (select data you want, remove empty cells, etc)
df = df.dropna()

# %%
# Play around with descriptive statistics to get a feel for your data
df.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# ...

# %%
# Based on your exploration, create a (OLS) regression analysis, and write what you've learned from your analysis
y = df[["int_memory"]]
x = df[["battery_power", "clock_speed"]]
OLSModel = sm.OLS(y, x).fit()
print(OLSModel.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:             int_memory   R-squared (uncentered):                   0.714
# Model:                            OLS   Adj. R-squared (uncentered):              0.713
# Method:                 Least Squares   F-statistic:                              1244.
# Date:                Sun, 13 Dec 2020   Prob (F-statistic):                   8.20e-272
# Time:                        19:37:16   Log-Likelihood:                         -4436.9
# No. Observations:                1000   AIC:                                      8878.
# Df Residuals:                     998   BIC:                                      8888.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# Create two graphs with your data that help you tell the story you are trying to build
# At least one of the graphs should relate back to your regression analysis
x = 'clock_speed'
y = 'battery_power'
plt.plot(x, y, data=df, linestyle='none', marker='o')
m, b = np.polyfit(df[x], df[y], 1)
plt.plot(df[x], m * df[x] + b)
plt.show()

df["battery_power"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Write a recommendation based on your analysis
# -------------------------------------------------------------------------------------------
# there is a very slight negative correlation between the clock speed and battery power of these phones
# the data is most dense between 500 and 2000 battery power

# %%
# Refer back to your past assignments to help you complete this project
